# %%
import pandas as pd
df = pd.read_csv("Mall_Customers.csv")
df.head()
# To check if the data is working or not , it will show the first 5 rows of the data .
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
pip install scikit-learn
# is used to download and install scikit-learn, which is the most popular open-source machine learning library for Python.
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.cluster import KMeans

X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

kmeans = KMeans(n_clusters=3)

df['Cluster'] = kmeans.fit_predict(X)

df.head()
# This code uses scikit-learn’s KMeans to group customers into 3 clusters based on their income and spending, 
# and assigns each customer a cluster label in the dataframe.
# Out:
# C:\Users\Hrithik\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        2
# 1        1
# 2        0
# 3        1
# 4        2

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'], c=df['Cluster'])

plt.xlabel("Income")
plt.ylabel("Spending Score")

plt.show()
# This code uses Matplotlib to create a scatter plot of customers’ income vs spending score, 
# where each point is colored based on its assigned cluster.
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn.cluster import KMeans

# Select features
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=42)

df['Cluster'] = kmeans.fit_predict(X)

df.head()
# runed the code again to check if it is woking or not .
# Out:
# C:\Users\Hrithik\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        2
# 1        0
# 2        1
# 3        0
# 4        2

# %%
import matplotlib.pyplot as plt

plt.plot(range(1, 11), wcss)

plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")

plt.title("Elbow Method")

plt.show()
# This code uses Matplotlib to plot the Elbow Method graph, 
# showing how WCSS changes with different numbers of clusters to help choose the optimal cluster count.

# %%
df.groupby('Cluster').mean(numeric_only=True) 
# This code groups the data by cluster and calculates the average values of all numeric columns for each cluster, 
# helping you understand the typical profile of each group.
# Out:
#          CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0          8.000000  25.428571           17.857143               82.285714
# 1          9.666667  46.833333           19.000000                9.500000
# 2          3.000000  25.000000           16.000000               39.500000

# %%
Project Insights & Reflections
Cluster 0: [High-value customers → Premium offers
Give:
VIP offers
Premium products
Loyalty rewards]
- Cluster 1: [Low spenders → Discounts
Give:
Discounts
Coupons
Deals]
- Cluster 2: [Medium customers → Personalized recommendations
Give:
Product recommendations
Targeted suggestions]

--------------------------------------------------------------------------------------------------
-----------------------Completed for sprint 3-----------------------------------------------------
--------------------------------------------------------------------------------------------------

# %%
SPRINT 4 : Stronger focus on advancement, refinement, and deeper implementation.

# %%
import pandas as pd

df = pd.read_csv("Mall_Customers.csv")

df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
✅ What was done:

The new customer dataset taken from kaggle.com was loaded into the notebook using Pandas.

🎯 Why it was done:

To import customer data into the analysis environment so it could be explored, processed, and used for clustering.

# %%
df.shape
# Out:
# (200, 5)

# %%
✅ What was done:

Checked the number of rows and columns in the dataset.

🎯 Why it was done:

To understand dataset size and overall structure before preprocessing.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
✅ What was done:

Inspected column names, datatypes, and missing values.

🎯 Why it was done:

To verify data quality and identify preprocessing requirements.

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
✅ What was done:

Generated statistical summary of numerical columns.

🎯 Why it was done:

To understand distributions, averages, minimums, maximums, and variability in customer behavior.

# %%
import matplotlib.pyplot as plt

plt.hist(df['Annual Income (k$)'])

plt.xlabel("Income")
plt.ylabel("Count")

plt.show()

# %%
Advanced Visualization
🔹 Income Distribution
✅ What was done:

Created histogram for annual income.

🎯 Why it was done:

To analyze how customer income values are distributed across the dataset.

# %%
plt.hist(df['Spending Score (1-100)'])

plt.xlabel("Spending Score")
plt.ylabel("Count")

plt.show()

# %%
🔹 Spending Distribution
✅ What was done:

Created histogram for spending score.

🎯 Why it was done:

To understand customer spending patterns and identify high and low spenders.

# %%
plt.scatter(df['Age'], df['Spending Score (1-100)'])

plt.xlabel("Age")
plt.ylabel("Spending Score")

plt.show()

# %%
🔹 Age vs Spending Scatter Plot
✅ What was done:

Visualized relationship between age and spending score.

🎯 Why it was done:

To identify behavioral patterns and possible customer trends across age groups.

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
Data Cleaning
🔹 Missing Values
✅ What was done:

Checked for null or missing values.

🎯 Why it was done:

To ensure dataset completeness and avoid errors during model training.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Duplicate Records
✅ What was done:

Checked for duplicate entries in the dataset.

🎯 Why it was done:

To maintain data consistency and prevent biased clustering results.

# %%
from sklearn.preprocessing import StandardScaler

X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
Feature Scaling
✅ What was done:

Applied StandardScaler to normalize Age, Income, and Spending Score.

🎯 Why it was done:

K-Means clustering is distance-based, so scaling ensures all features contribute equally without larger values dominating the model.

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\mnava\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mnava\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\mnava\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
plt.plot(range(1, 11), wcss)

plt.xlabel("Clusters")
plt.ylabel("WCSS")

plt.title("Elbow Method")

plt.show()

# %%
Better Elbow Method
✅ What was done:

Calculated WCSS values for multiple cluster counts and plotted the Elbow graph.

🎯 Why it was done:

To identify the optimal number of clusters instead of selecting a random value.

# %%
kmeans = KMeans(n_clusters=5, random_state=42)

df['Cluster'] = kmeans.fit_predict(X_scaled)
# Out:
# C:\Users\mnava\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
Apply Improved Clustering
✅ What was done:

Applied K-Means clustering with the selected optimal number of clusters.

🎯 Why it was done:

To segment customers into meaningful groups based on behavioral similarity.

# %%
plt.scatter(
    df['Annual Income (k$)'],
    df['Spending Score (1-100)'],
    c=df['Cluster']
)

plt.xlabel("Income")
plt.ylabel("Spending Score")

plt.show()

# %%
Better Visualization
✅ What was done:

Created cluster visualization using scatter plot with color-coded segments.

🎯 Why it was done:

To visually analyze customer segmentation and understand cluster separation.

# %%
df.groupby('Cluster').mean(numeric_only=True)
# Out:
#          CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0         68.775862  55.275862           47.620690               41.706897
# 1        161.025000  32.875000           86.100000               81.525000
# 2         23.461538  25.769231           26.115385               74.846154
# 3         86.377778  26.733333           54.311111               40.911111
# 4        166.870968  44.387097           89.774194               18.483871

# %%
Cluster Analysis
✅ What was done:

Calculated average values for each cluster using groupby() to analyze customer behavior patterns across different segments.

🎯 Why it was done:

To interpret customer characteristics and identify high-value, medium, and low-spending customer groups.

📌 Conclusion:

The analysis showed that different customer segments have distinct spending behaviors and income patterns. 
This helped in identifying premium customers, budget-conscious customers, and average shoppers, enabling more targeted marketing 
and personalized recommendation strategies.
